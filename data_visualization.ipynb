# %%
# matplotlib inline

# %%
from glob import glob
import pandas as pd
import numpy as np

# %%
segment_list = glob("train/*")

# %%
df = pd.read_csv(segment_list[0])

# %%
df.plot()

# %%
df1 = pd.read_csv(segment_list[1])

# %%
df1.plot()

# %%
df1 = pd.read_csv(segment_list[2])
df1.plot()
